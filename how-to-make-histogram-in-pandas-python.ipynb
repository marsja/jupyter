# %% [markdown]
# ## Plotting a Histogram with Pandas
# In this Jupyter Notebook, you will find the example code for the blog post about [how to plot a histogram with Pandas](https://www.marsja.se/how-to-plot-a-histogram-with-pandas-in-3-simple-steps/).

# %% [markdown]
# First step is to import pandas as pd:

# %%
import pandas as pd

# %% [markdown]
# Second step is to load data into a pandas dataframe:

# %%
from pathlib import Path

datafile = Path('SimData', 'play_data.xlsx')

df = pd.read_excel(datafile, 
               index_col=0)
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-29e53df1a76d> in <module>
#       4
#       5 df = pd.read_excel(datafile,
# ----> 6                index_col=0)
#       7 df.head()
#
# C:\ProgramData\new_Anaconda3\envs\PYJOS\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     206                 else:
#     207                     kwargs[new_arg_name] = new_arg_value
# --> 208             return func(*args, **kwargs)
#     209
#     210         return wrapper
#
# C:\ProgramData\new_Anaconda3\envs\PYJOS\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, verbose, parse_dates, date_parser, thousands, comment, skip_footer, skipfooter, convert_float, mangle_dupe_cols, **kwds)
#     308
#     309     if not isinstance(io, ExcelFile):
# --> 310         io = ExcelFile(io, engine=engine)
#     311     elif engine and engine != io.engine:
#     312         raise ValueError(
#
# C:\ProgramData\new_Anaconda3\envs\PYJOS\lib\site-packages\pandas\io\excel\_base.py in __init__(self, io, engine)
#     817         self._io = _stringify_path(io)
#     818
# --> 819         self._reader = self._engines[engine](self._io)
#     820
#     821     def __fspath__(self):
#
# C:\ProgramData\new_Anaconda3\envs\PYJOS\lib\site-packages\pandas\io\excel\_xlrd.py in __init__(self, filepath_or_buffer)
#      19         err_msg = "Install xlrd >= 1.0.0 for Excel support"
#      20         import_optional_dependency("xlrd", extra=err_msg)
# ---> 21         super().__init__(filepath_or_buffer)
#      22
#      23     @property
#
# C:\ProgramData\new_Anaconda3\envs\PYJOS\lib\site-packages\pandas\io\excel\_base.py in __init__(self, filepath_or_buffer)
#     357             self.book = self.load_workbook(filepath_or_buffer)
#     358         elif isinstance(filepath_or_buffer, str):
# --> 359             self.book = self.load_workbook(filepath_or_buffer)
#     360         else:
#     361             raise ValueError(
#
# C:\ProgramData\new_Anaconda3\envs\PYJOS\lib\site-packages\pandas\io\excel\_xlrd.py in load_workbook(self, filepath_or_buffer)
#      34             return open_workbook(file_contents=data)
#      35         else:
# ---> 36             return open_workbook(filepath_or_buffer)
#      37
#      38     @property
#
# C:\ProgramData\new_Anaconda3\envs\PYJOS\lib\site-packages\xlrd\__init__.py in open_workbook(filename, logfile, verbosity, use_mmap, file_contents, encoding_override, formatting_info, on_demand, ragged_rows)
#     109     else:
#     110         filename = os.path.expanduser(filename)
# --> 111         with open(filename, "rb") as f:
#     112             peek = f.read(peeksz)
#     113     if peek == b"PK\x03\x04": # a ZIP file
#
# FileNotFoundError: [Errno 2] No such file or directory: 'SimData\\play_data.xlsx'

# %% [markdown]
# The final step is to use Pandas hist():

# %%
df.hist(column='RT')

# %% [markdown]
# How to Group a Histogram:

# %%
df.hist(by='Gender',
       column='RT')

# %% [markdown]
# Change the size of the histogram:

# %%
df.hist(by='Gender',
       column='RT',
       figsize=[10, 6])

# %%
df.hist()
