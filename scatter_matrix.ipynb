# %% [markdown]
# ## Pandas Scatter Matrix Tutorial
# In this notebook, you will find the code for the [Pandas scatter_matrix tutorial](https://www.marsja.se/pandas-scatter-matrix-pair-plot/). Feel free to use this code but if you find it usefule; please link to the blog post.

# %% [markdown]
# ## Simulate Data

# %%
# %matplotlib inline
import numpy as np
import pandas as pd

np.random.seed(134)                     
N = 1000                              
 
x1 = np.random.normal(0, 1, N)                        
x2 = x1 + np.random.normal(0, 3, N)              
x3 = 2 * x1 - x2 + np.random.normal(0, 2, N)  
 
df = pd.DataFrame({'x1':x1,
                   'x2':x2,
                   'x3':x3})

df.head()
# Out:
#          x1        x2         x3
# 0 -0.224315 -8.840152  10.145993
# 1  1.337257  2.383882  -1.854636
# 2  0.882366  3.544989  -1.117054
# 3  0.295153 -3.844863   3.634823
# 4  0.780587 -0.465342   2.121288

# %% [markdown]
# ### Example 1

# %%
pd.plotting.scatter_matrix(df)

# %% [markdown]
# ### Example 2

# %%
pd.plotting.scatter_matrix(df, hist_kwds={'bins':30})

# %% [markdown]
# ### Example 3

# %%
pd.plotting.scatter_matrix(df, diagonal='kde')

# %% [markdown]
# ### Example 4

# %%
pd.plotting.scatter_matrix(df, marker='+')

# %% [markdown]
# ### From CSV File (Summary)

# %%
csv_file = 'https://vincentarelbundock.github.io/Rdatasets/csv/MASS/survey.csv'
df_s = pd.read_csv(csv_file, index_col=0)

df_s.head()
# Out:
#       Sex  Wr.Hnd  NW.Hnd  W.Hnd     Fold  Pulse     Clap  Exer  Smoke  \
# 1  Female    18.5    18.0  Right   R on L   92.0     Left  Some  Never
# 2    Male    19.5    20.5   Left   R on L  104.0     Left  None  Regul
# 3    Male    18.0    13.3  Right   L on R   87.0  Neither  None  Occas
# 4    Male    18.8    18.9  Right   R on L    NaN  Neither  None  Never
# 5    Male    20.0    20.0  Right  Neither   35.0    Right  Some  Never
#
#    Height       M.I     Age
# 1   173.0    Metric  18.250
# 2   177.8  Imperial  17.583
# 3     NaN       NaN  16.917
# 4   160.0    Metric  20.333
# 5   165.0    Metric  23.667

# %%
pd.plotting.scatter_matrix(df_s.iloc[:, 1:9])
